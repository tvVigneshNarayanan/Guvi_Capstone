# %%
from googleapiclient.discovery import build
from pymongo import MongoClient
import pymongo
import psycopg2

# %%
def APi_connect():
    Api_Id = 'AIzaSyCI8yMCeC3FQFEZ2GFearr7elnoeXjdqp4'
    api_service_name = "youtube"
    api_version = "v3"
    youtube = build('youtube', 'v3', developerKey=Api_Id)
    return youtube
youtube = APi_connect()

# %%
def get_channel_info(channel_id):
    request = youtube.channels().list(
        part='snippet,statistics,ContentDetails',
        id=channel_id
    )
    response = request.execute()

    for i in response["items"]:
        data = dict(

            Channel_Id=i['id'],
            Channel_Name=i['snippet']['title'],
            Subscription_Count=i["statistics"]["subscriberCount"],
            Channel_Views=i["statistics"]["viewCount"],
            Total_Videos=i["statistics"]["videoCount"],
            Channel_Description=i["snippet"]["description"],
            Playlist_Id=i["contentDetails"]["relatedPlaylists"]["uploads"]
          #  Playlist_Id = i.get("contentDetails", {}).get("relatedPlaylists", {}).get("uploads")

        )

    return data

# %%
channel_details=get_channel_info("UCvyZS6W6zMJCZBVzF-Ei6sw")

# %%
channel_details
# Out:
# {'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#  'Channel_Name': 'A2D Channel',
#  'Subscription_Count': '1210000',
#  'Channel_Views': '254156153',
#  'Total_Videos': '840',
#  'Channel_Description': "we make videos...\n\n\nFor Sponsorships: collab@a2dmediagroup.com\n\nA2D PC Factory(for Soldier PC Builds): enquiries@a2dpcfactory.com / +91 9445747768 / +91 9025380083 (be patient, don't spam)\n",
#  'Playlist_Id': 'UUvyZS6W6zMJCZBVzF-Ei6sw'}

# %%
def get_video_ids(channel_id):
    video_ids=[]
    response = youtube.channels().list(id=channel_id,
                                    part='contentDetails').execute()
    Playlist_Id=response['items'][0]['contentDetails']['relatedPlaylists']['uploads']

    next_page_token=None

    while True:
     response1=youtube.playlistItems().list(
                                        part='snippet',
                                        playlistId=Playlist_Id,
                                        maxResults=40,
                                        pageToken=next_page_token).execute()
     for i in range(len(response1['items'])):
      video_ids.append(response1['items'][0]['snippet']['resourceId']['videoId'])
     next_page_token=response1.get('nextPageToken') 

     if next_page_token is None:
      break

    return video_ids

# %%
Video_Ids=get_video_ids("UCvyZS6W6zMJCZBVzF-Ei6sw")

# %%
Video_Ids
# Out:
# ['NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'NDbFFCo9JLU',
#  'yC0Z77DsQ7g',
#  'yC0Z77DsQ7g',
#  'yC0Z77DsQ7g',
#  'yC0Z77DsQ7g',
#  'yC0Z77DsQ7g',
#  'yC0Z77DsQ7g',
#  'yC0Z77DsQ7g',
#  'yC0Z77DsQ7g',
#  'yC0Z77DsQ7g',
#  'yC0Z77DsQ7g',
#  'yC0Z77DsQ7g',
#  'yC0Z77DsQ7g',
#  'yC0Z77DsQ7g',
#  'yC0Z77DsQ7g',
#  'yC0Z77DsQ7g',
# ...

# %%
def get_video_info(video_ids):
 video_data=[]
 for video_id in Video_Ids:
    request = youtube.videos().list(
        part="snippet,ContentDetails,statistics",
        id=video_id
    )
    response=request.execute()

    for item in response['items']:
       data=dict(Channel_Name=item['snippet']['channelTitle'],
                  Channel_Id=item['snippet']['channelId'],
                  Video_Id=item['id'],
                  Title=item['snippet']['title'],
                  Tags=item.get('tags'),
                  Thumbnail=item['snippet']['thumbnails'],
                  Description=item.get('description'),
                  Published_Date=item['snippet']['publishedAt'],
                  Duration=item['contentDetails']['duration'],
                  Views=item.get('viewCount'),
                  Comments=item.get('commentCount'),
                  Favorite_Count=item['statistics']['favoriteCount'],
                  Definition=item['contentDetails']['definition'],
                  Caption_Status=item['contentDetails']['caption']
                  )
    video_data.append(data)

 return video_data

# %%
video_details=get_video_info(Video_Ids)

# %%
video_details
# Out:
# [{'Channel_Name': 'A2D Channel',
#   'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
#   'Video_Id': 'NDbFFCo9JLU',
#   'Title': 'Rs.10,000/-  வடக்கு குட்டி பெட்டி PC 😳 | Gaming on 10K PC 😱 | Mini PC Worth-ஆ 🤔?',
#   'Tags': None,
#   'Thumbnail': {'default': {'url': 'https://i.ytimg.com/vi/NDbFFCo9JLU/default.jpg',
#     'width': 120,
#     'height': 90},
#    'medium': {'url': 'https://i.ytimg.com/vi/NDbFFCo9JLU/mqdefault.jpg',
#     'width': 320,
#     'height': 180},
#    'high': {'url': 'https://i.ytimg.com/vi/NDbFFCo9JLU/hqdefault.jpg',
#     'width': 480,
#     'height': 360},
#    'standard': {'url': 'https://i.ytimg.com/vi/NDbFFCo9JLU/sddefault.jpg',
#     'width': 640,
#     'height': 480},
#    'maxres': {'url': 'https://i.ytimg.com/vi/NDbFFCo9JLU/maxresdefault.jpg',
#     'width': 1280,
#     'height': 720}},
#   'Description': None,
#   'Published_Date': '2024-02-09T11:15:04Z',
#   'Duration': 'PT12M31S',
#   'Views': None,
#   'Comments': None,
#   'Favorite_Count': '0',
# ...

# %%
data
# Out:
# {'Channel_Name': 'A2D Channel'}

# %%
def get_comment_info(video_ids):
    Comment_data = []   
    try:
        for video_id in video_ids:
            request = youtube.commentThreads().list(
                part="snippet",
                videoId=video_id,
                maxResults=50
            )
            response = request.execute()

            for item in response['items']:
                    data = dict(
                        Comment_Id=item['snippet']['topLevelComment']['id'],
                        Video_Id=item['snippet']['topLevelComment']['snippet']['videoId'],
                        Comment_Text=item['snippet']['topLevelComment']['snippet']['textDisplay'],
                        Comment_Author=item['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                        Comment_Published=item['snippet']['topLevelComment']['snippet']['publishedAt'])
                    Comment_data.append(data)
                    
    except:
     pass
    return Comment_data

# %%
comment_details=get_comment_info(Video_Ids)

# %%
comment_details
# Out:
# [{'Comment_Id': 'Ugy0ZK8qYFQQFG4o0px4AaABAg',
#   'Video_Id': 'NDbFFCo9JLU',
#   'Comment_Text': 'Pc என்றால் என்ன?',
#   'Comment_Author': '@josephfernandaz3558',
#   'Comment_Published': '2024-02-09T18:13:36Z'},
#  {'Comment_Id': 'UgwrZEnZ3bRa-CcgExp4AaABAg',
#   'Video_Id': 'NDbFFCo9JLU',
#   'Comment_Text': 'Bro yanaku laptop vanum engineering designing software la use pananum ( aadiku yatha mather laptop solunga) low price',
#   'Comment_Author': '@jeevanandam2357',
#   'Comment_Published': '2024-02-09T18:07:47Z'},
#  {'Comment_Id': 'UgwQgX0zKSRa2o94_X54AaABAg',
#   'Video_Id': 'NDbFFCo9JLU',
#   'Comment_Text': 'Bro. Iqoo z6 mobile ku real time fps Katra Mari app iruntha sollunga',
#   'Comment_Author': '@sanjay.d9323',
#   'Comment_Published': '2024-02-09T18:03:55Z'},
#  {'Comment_Id': 'UgxNtTlNHYVQ3ATQQwd4AaABAg',
#   'Video_Id': 'NDbFFCo9JLU',
#   'Comment_Text': 'Waiting for Ganesa to open his YouTube channel 🔥',
#   'Comment_Author': '@sridharanyezz',
# ...

# %%
len(comment_details)
# Out:
# 42100

# %%
Comment_data
# Out:
# [{'Comment_Id': 'UgyFwZR0MDUbKxX7fu94AaABAg',
#   'Video_Id': 'AMnAfUw0QU4',
#   'Comment_Text': 'Bro i am from future you just reached 3 million subs in 2025 advance congrats 🔥',
#   'Comment_Author': '@Fearless-gamers-tamil',
#   'Comment_Published': '2024-02-07T07:08:18Z'},
#  {'Comment_Id': 'UgxmdTRr-6spkoMcLSB4AaABAg',
#   'Video_Id': 'AMnAfUw0QU4',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@user-em5jz7kb4r',
#   'Comment_Published': '2024-01-24T07:48:55Z'},
#  {'Comment_Id': 'UgxpTEKzO4V3BQjgQC54AaABAg',
#   'Video_Id': 'AMnAfUw0QU4',
#   'Comment_Text': '👻',
#   'Comment_Author': '@bairavaa4942',
#   'Comment_Published': '2024-01-15T15:26:35Z'},
#  {'Comment_Id': 'UgzWgJG9WUHTeLkOFGh4AaABAg',
#   'Video_Id': 'AMnAfUw0QU4',
#   'Comment_Text': 'Watching again in 2024 after 2023',
#   'Comment_Author': '@opsgigithegamergod',
#   'Comment_Published': '2024-01-15T15:08:57Z'},
#  {'Comment_Id': 'UgyNTv-8ZCruQ_RGZxZ4AaABAg',
#   'Video_Id': 'AMnAfUw0QU4',
# ...

# %%
response['items'][0]['snippet']['topLevelComment']['snippet']['publishedAt']
# Out:
# '2024-02-09T17:56:46Z'

# %%
def get_playlist_details(channel_id):
 next_page_token=None
 All_data=[]
 while True:
  request = youtube.playlists().list(
        part='snippet,contentDetails',
        channelId=channel_id,
        maxResults=50,
        pageToken=next_page_token
)
  response = request.execute()

  for item in response['items']:
    data=dict(Playlist_Id=item['id'],
              Title=item['snippet']['title'],
              Channel_Id=item['snippet']['channelId'],
              Channel_Name=item['snippet']['channelTitle'],
              PublishedAt=item['snippet']['publishedAt'],
              Video_Count=item['contentDetails']['itemCount'])
    All_data.append(data)


  next_page_token = response.get('nextPageToken')
  if next_page_token is None:
   break
  
  return All_data

# %%
playlist_details=get_playlist_details('UCvyZS6W6zMJCZBVzF-Ei6sw')

# %%
playlist_details

# %%
client=pymongo.MongoClient('mongodb://localhost:27017/')
db=client["YouTube_Har"]
collection1=db["Channel_details"]
x={"Name":"Vignesh","Initial":"T"}
collection1.insert_one(x)
# Out:
# InsertOneResult(ObjectId('65c797c2b1d1026f4178d3d3'), acknowledged=True)

# %%
def Channel_details(channel_id):
    ch_details=get_channel_info(channel_id)
    pl_details=get_playlist_details(channel_id)
    vi_ids=get_video_ids(channel_id)
    vi_details=get_video_info(vi_ids)
    com_details=get_comment_info(vi_ids)
    
    Coll_First=db["Channel_details"]
    Coll_First.insert_one({"channel_information":ch_details,"Playlist_information":pl_details,"Video_Infromation":vi_details,"Comment_Information":com_details})
    
    return "Uploaded Success"

# %%
insert=Channel_details("UCvyZS6W6zMJCZBVzF-Ei6sw")

# %%
create_query = '''CREATE TABLE IF NOT EXISTS channel (
                    Channel_Name varchar(100),
                    Channel_Id varchar(100) PRIMARY KEY,
                    Subscription_Count bigint,
                    Channel_Views bigint,
                    Total_Videos int,
                    Channel_Description text,
                    Playlist_Id varchar(100)
                )'''

# %%
import psycopg2

mydb = psycopg2.connect(
    host="localhost",
    user="postgres",
    password="admin",
    database="Youtube_Data",
    port="5432"
)
cursor = mydb.cursor()

try:
    create_query = '''CREATE TABLE IF NOT EXISTS channel (
                        Channel_Name varchar(100),
                        Channel_Id varchar(100) PRIMARY KEY,
                        Subscription_Count bigint,
                        Channel_Views bigint,
                        Total_Videos int,
                        Channel_Description text,
                        Playlist_Id varchar(100)
                    )'''

    cursor.execute(create_query)
    mydb.commit()

    print("Channel table created")

except Exception as e:
    print(f"Error: {e}")
# Out:
# Channel table created

# %%
{'Channel_Id': 'UCvyZS6W6zMJCZBVzF-Ei6sw',
 'Channel_Name': 'A2D Channel',
 'Subscription_Count': '1210000',
 'Channel_Views': '254156153',
 'Total_Videos': '840',
 'Channel_Description': "we make videos...\n\n\nFor Sponsorships: collab@a2dmediagroup.com\n\nA2D PC Factory(for Soldier PC Builds): enquiries@a2dpcfactory.com / +91 9445747768 / +91 9025380083 (be patient, don't spam)\n",
 'Playlist_Id': 'UUvyZS6W6zMJCZBVzF-Ei6sw'}
